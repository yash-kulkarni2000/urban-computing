# %%
import pandas as pd

# %%
data = pd.read_csv('D:\VTacademics\sem3\urbanComputing\final_project\urban-computing\Data\new_york_tree_census_2015.csv')
# Out:
#   Cell In[3], line 1
#     data = pd.read_csv('D:\VTacademics\sem3\urbanComputing\final_project\urban-computing\Data\new_york_tree_census_2015.csv')
#                                                                                                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 19-20: truncated \uXXXX escape
